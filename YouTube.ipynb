# %%
api_key='AIzaSyDxhVA3kzI32KKLGcyZ0loQNtQskG6slmE'
import pandas as pd
import seaborn as sns
import numpy as np
import pprint as pp
# %pip install google-api-python-client
from googleapiclient.discovery import build

youtube=build('youtube','v3', developerKey=api_key)
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
hashtag=youtube.videos()\
.list(part='snippet', maxResults=50\
      ,id='ZIdM9GAWur4,wPMANQ9jNSA,xebY1_S-ve4,JQaUW36pMw,CEPnLJqU8d0,SkNDiZ7Kv6k,4_lAaE9fNg0,sqsWZGGWDdI,IjiEL9anDYY,QnPDBv0LrKc,A75BZQxZ6RU,JZCOdmjJvgY,ZPHR43HkDd4,EXZAYIdhk9c,Te01T8OCgl0,8cHPqTSxWLM,mSegsxQPPeQ,Sm6WAF_8aak,sPhhe4XQNbE,qe8USGpT508,JAQzc00tFCg,uy4-gePx5xU,GXc4J8VQwH0,AwiRccLg3RE,zaYqW9s9Aok,NSPYNaKEW8E,H_sJFjKuqWA,jty1Pb4dHvc,Kfs2nIDRHHI,fe8YDMklxI8,T9a9Y7u-8A4')\
.execute()

pp.pprint(hashtag['items'])
# Out:
# [{'etag': 'DZ6jbGM_u5OCgrfWDVDQ5lyMTvc',
#   'id': 'ZIdM9GAWur4',
#   'kind': 'youtube#video',
#   'snippet': {'categoryId': '24',
#               'channelId': 'UCN2bQLTTvNPZWCWU5TYghKA',
#               'channelTitle': 'Jessi',
#               'defaultAudioLanguage': 'ko',
#               'description': "Jessi (제시) - '눈누난나 (NUNU NANA)' MV Behind The "
#                              'Scenes\n'
#                              '\n'
#                              "* '눈누난나 (NUNU NANA)' is now available on all "
#                              'streaming platforms including Apple Music & '
#                              'Spotify. \n'
#                              '\n'
#                              '- Spotify: '
#                              'https://open.spotify.com/artist/64k5e9kV9MdukXjFrR5R37 \n'
#                              '- iTunes & Apple Music: '
#                              'https://music.apple.com/us/artist/jessi/911707693 \n'
#                              '\n'
# ...

# %%
pp.pprint(hashtag['items'][0]['snippet']['description'])
# Out:
# ("제시(Jessi) with 스트릿 우먼 파이터 (SWF) 'Cold Blooded' MV Behind The Scenes\n"
#  '\n'
#  '\n'
#  "* ‘Cold Blooded' is now available on all streaming platforms including Apple "
#  'Music & Spotify. \n'
#  '\n'
#  '\n'
#  '🎧 Spotify : https://spoti.fi/3lvmGt2\n'
#  '🎧 iTunes & Apple Music : https://apple.co/2YEXirI\n'
#  '🎧 Melon : https://bit.ly/3oPClp7\n'
#  '🎧 Genie : https://bit.ly/3AztdHs\n'
#  '🎧 FLO : https://bit.ly/3v1rNEg\n'
#  '🎧 Bugs : https://bit.ly/3AztkTo\n'
#  '🎧 VIBE : https://bit.ly/3iUuVNp\n'
#  '\n'
#  '\n'
#  '- Jessi Official YouTube: https://www.youtube.com/jessiofficial\n'
#  '- Jessi Official Instagram: https://www.instagram.com/jessicah_o\n'
#  '- Jessi Official Facebook: https://www.facebook.com/jessihomusic \n'
#  '- Jessi Official Tiktok: https://www.tiktok.com/@itsjessibaby \n'
#  '- Jessi Official Weibo: https://weibo.com/u/7107198887\n'
#  '- Jessi Official Douyin: https://v.douyin.com/e89syA5\n'
#  '\n'
#  '\n'
# ...

# %%
for s in range(len(hashtag['items'])):
    pp.pprint(hashtag['items'][s]['snippet']['description'])
# Out:
# ("제시(Jessi) with 스트릿 우먼 파이터 (SWF) 'Cold Blooded' MV Behind The Scenes\n"
#  '\n'
#  '\n'
#  "* ‘Cold Blooded' is now available on all streaming platforms including Apple "
#  'Music & Spotify. \n'
#  '\n'
#  '\n'
#  '🎧 Spotify : https://spoti.fi/3lvmGt2\n'
#  '🎧 iTunes & Apple Music : https://apple.co/2YEXirI\n'
#  '🎧 Melon : https://bit.ly/3oPClp7\n'
#  '🎧 Genie : https://bit.ly/3AztdHs\n'
#  '🎧 FLO : https://bit.ly/3v1rNEg\n'
#  '🎧 Bugs : https://bit.ly/3AztkTo\n'
#  '🎧 VIBE : https://bit.ly/3iUuVNp\n'
#  '\n'
#  '\n'
#  '- Jessi Official YouTube: https://www.youtube.com/jessiofficial\n'
#  '- Jessi Official Instagram: https://www.instagram.com/jessicah_o\n'
#  '- Jessi Official Facebook: https://www.facebook.com/jessihomusic \n'
#  '- Jessi Official Tiktok: https://www.tiktok.com/@itsjessibaby \n'
#  '- Jessi Official Weibo: https://weibo.com/u/7107198887\n'
#  '- Jessi Official Douyin: https://v.douyin.com/e89syA5\n'
#  '\n'
#  '\n'
# ...

# %%
des = []
for s in range(len(hashtag['items'])):
    des.append(hashtag['items'][s]['snippet']['description'])

# %%
des
# Out:
# ["제시(Jessi) with 스트릿 우먼 파이터 (SWF) 'Cold Blooded' MV Behind The Scenes\n\n\n* ‘Cold Blooded' is now available on all streaming platforms including Apple Music & Spotify. \n\n\n🎧 Spotify : https://spoti.fi/3lvmGt2\n🎧 iTunes & Apple Music : https://apple.co/2YEXirI\n🎧 Melon : https://bit.ly/3oPClp7\n🎧 Genie : https://bit.ly/3AztdHs\n🎧 FLO : https://bit.ly/3v1rNEg\n🎧 Bugs : https://bit.ly/3AztkTo\n🎧 VIBE : https://bit.ly/3iUuVNp\n\n\n- Jessi Official YouTube: https://www.youtube.com/jessiofficial\n- Jessi Official Instagram: https://www.instagram.com/jessicah_o\n- Jessi Official Facebook: https://www.facebook.com/jessihomusic \n- Jessi Official Tiktok: https://www.tiktok.com/@itsjessibaby \n- Jessi Official Weibo: https://weibo.com/u/7107198887\n- Jessi Official Douyin: https://v.douyin.com/e89syA5\n\n\n-  P NATION Official Instagram: https://www.instagram.com/pnation.official\n-  P NATION Official Facebook: https://www.facebook.com/pnation.official\n-  P NATION Official Twitter: https:/
# ...

# %%
num = 0
for i in range(len(des)):
   num += des[i].count("#")

print(num)
# Out:
# 171

# %%
des2 = []
for s in range(len(hashtag['items'])):
    des2.append(hashtag['items'][s]['snippet']['description'])

# %%
a = 0
for i in range(len(des)):
   a += des2[i].count("#")

print(a)
# Out:
# 145

# %%
145+171
# Out:
# 316

# %%
hashtag=youtube.videos()\
.list(part='snippet', maxResults=50\
      ,id='yQeqUiAsV0w,SmQhRHS9-YA,3nDzKulmSpg,TyOwx0Okc1A,nvJeJSrghOI,JpTqSzm4JOk,R16Oupo81jw,bgQIzPnPI88,DkO0z4-FHJ0,SXRNesWYvV4,mVd8C-jEyxA,mg2bL8iCy-k,9y_97VDjLe8,DPiylXA6WQ8,tW5bSCpOVQ4,mrBwXXj0p34,u35cyBQpwNo,c9E2IT1jHQY,nvuJXEuYNr8,ECZHKqbasBU,5eW6NarieZk,PFwfb5x3PR4,h61L-LhDBv4,L1vjymW7eNg,0SQOmwa25dw,ZINbc0pLh8g,Y-4m_bwhdVA,z90qbcmpwmQ,oN5GJQK6Taw,QhQZ8xl268c,2LnCaecCDd0,DUzIyzoNt3Q,rfjnzoYLvIU,cFppUAKWM_E,iMPUsHbaXLw,J4BZNlUNUsA,b_ygRc5qOPc,ZAghZAZ23x8,Saq93gLaH9I,3iM_06QeZi8')\
.execute()

# %%
for s in range(len(hashtag['items'])):
    pp.pprint(hashtag['items'][s]['snippet']['description'])
# Out:
# '[IU TV] 토요일 토요일은 아이유\n[IU TV] IU in the saturday night\n\n#IU #아이유 #dlwlrma'
# "[IU] '겨울잠 (Winter Sleep)' Live Clip\n\n#아이유 #조각집 #겨울잠"
# "* '정거장' - 조각집 선공개 Live Clip\n 2021. 12. 29. 6PM 조각집 발매\n\n#아이유 #조각집 #정거장"
# '[IU TV] 한 겨울의 라일락\n[IU TV] LILAC in the winter\n\n#IU #아이유 #dlwlrma'
# '[MMA 2021] IU - Lilac\n\n#IU #Lilac #MMA2021'
# '[MMA 2021] IU -  strawberry moon + Celebrity\n\n#IU #strawberrymoon #Celebrity'
# "[IU] '꿈빛 파티시엘' Bonus Cut #shorts\n\n#아이유 #IU #dlwlrma"
# ("[IU] '꿈빛 파티시엘' dlwlrma Clip\n"
#  '\n'
#  '* 이지금 채널의 700만 구독자 달성과 더불어\n'
#  '11년 전 추억을 기리며 많은 참여와 큰 사랑 보내주신 \n'
#  "'꿈빛 파티시엘' 챌린지에 힘입어 본 라이브 영상을 드립니다\n"
#  '\n'
#  '* In celebration of the dlwlrma Youtube channel reaching 7 million '
#  'subscribers,\n'
#  "and for your love & support for the 'Yumiero Patissiere' challenge to bring "
#  'back memories \n'
#  'from 11 years ago, we present to you, this live video\n'
#  '\n'
#  '#아이유 #IU #dlwlrma')
# ...

# %%
des = []
for s in range(len(hashtag['items'])):
    des.append(hashtag['items'][s]['snippet']['description'])

# %%
num = 0
for i in range(len(des)):
   num += des[i].count("#")

print(num)
# Out:
# 115

# %%
115/40*92
# Out:
# 264.5

# %%
hashtag=youtube.videos()\
.list(part='snippet', maxResults=50\
      ,id='DOBjwlfIZdE&list=PLvdEQOT_E6yK-CgdGdf4EfLfgt7NdlQat,H8kqPkEXP_E&list=PLvdEQOT_E6yK-CgdGdf4EfLfgt7NdlQat&index=2,tg2uF3R_Ozo&list=PLvdEQOT_E6yK-CgdGdf4EfLfgt7NdlQat&index=3,lBYyAQ99ZFI&list=PLvdEQOT_E6yK-CgdGdf4EfLfgt7NdlQat&index=4,oDJ4ct59NC4&list=PLvdEQOT_E6yK-CgdGdf4EfLfgt7NdlQat&index=5')\
.execute()

# %%
for s in range(len(hashtag['items'])):
    pp.pprint(hashtag['items'][s]['snippet']['description'])

# %%
des = []
for s in range(len(hashtag['items'])):
    des.append(hashtag['items'][s]['snippet']['description'])

# %%
num = 0
for i in range(len(des)):
   num += des[i].count("#")

print(num)
# Out:
# 0

# %%
201/20*123
# Out:
# 1236.15

# %%
82/20*199
# Out:
# 815.9

# %%
51/10*27*5
# Out:
# 688.5

# %%
38/10*185
# Out:
# 703.0

# %%
76/15*51*5
# Out:
# 1292.0

# %%
7*69+20+20*8
# Out:
# 663
